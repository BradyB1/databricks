# %%
import pandas as pd
import numpy as np
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date

# %%
df = spark.read.table("dataengineering.v1.users_dirty_csv")

df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("dataengineering.v1.bronze")
